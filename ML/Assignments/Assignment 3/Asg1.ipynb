# %%
import pandas as pd
import numpy as np

# Calculate the number of rows in the CSV (assuming the file has a header row)
row_count = 11000000  # Replace this with the actual row count if known

# Randomly choose 10% of the rows to skip
skip = sorted(np.random.choice(np.arange(1, row_count), int(row_count * 0.999), replace=False))

# Load the remaining 10% of the data
df = pd.read_csv('HIGGS.csv', skiprows=skip)

print(df.shape)  # Check the size of the sampled data
# Out:
# (10999, 29)

# %%
df.columns = ['feature_' + str(i) for i in range(1, 29)] + ['target']  # Rename columns
df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0        0.0   0.917608  -1.183426   1.706060   0.656796  -0.907555
# 1        0.0   1.055596   0.704125   1.188375   1.549320  -1.728858
# 2        0.0   0.642728  -1.665541  -0.531798   1.339529   1.096409
# 3        0.0   0.371874   0.716787   0.157442   0.534731  -1.075644
# 4        1.0   1.834300   0.114874   0.305590   0.416167  -0.468590
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_20  feature_21  \
# 0   0.633189  -1.169487  -0.808778    0.000000  ...   -1.330480    1.559696
# 1   1.054307  -2.541946  -0.295424    0.000000  ...    0.360152   -0.620104
# 2   1.029848   1.135768  -0.410179    0.000000  ...   -0.914068    1.361593
# 3   0.701345   0.089095   1.661624    0.000000  ...   -0.948214    1.549708
# 4   1.442630  -0.024781  -1.363708    2.173076  ...   -1.891802    0.377734
#
#    feature_22  feature_23  feature_24  feature_25  feature_26  feature_27  \
# ...

# %%
print(df.isnull().sum())  # Check for missing values
# Out:
# feature_1     0
# feature_2     0
# feature_3     0
# feature_4     0
# feature_5     0
# feature_6     0
# feature_7     0
# feature_8     0
# feature_9     0
# feature_10    0
# feature_11    0
# feature_12    0
# feature_13    0
# feature_14    0
# feature_15    0
# feature_16    0
# feature_17    0
# feature_18    0
# feature_19    0
# feature_20    0
# feature_21    0
# feature_22    0
# feature_23    0
# feature_24    0
# feature_25    0
# feature_26    0
# feature_27    0
# feature_28    0
# target        0
# dtype: int64

# %%
df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0        0.0   0.917608  -1.183426   1.706060   0.656796  -0.907555
# 1        0.0   1.055596   0.704125   1.188375   1.549320  -1.728858
# 2        0.0   0.642728  -1.665541  -0.531798   1.339529   1.096409
# 3        0.0   0.371874   0.716787   0.157442   0.534731  -1.075644
# 4        1.0   1.834300   0.114874   0.305590   0.416167  -0.468590
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_20  feature_21  \
# 0   0.633189  -1.169487  -0.808778    0.000000  ...   -1.330480    1.559696
# 1   1.054307  -2.541946  -0.295424    0.000000  ...    0.360152   -0.620104
# 2   1.029848   1.135768  -0.410179    0.000000  ...   -0.914068    1.361593
# 3   0.701345   0.089095   1.661624    0.000000  ...   -0.948214    1.549708
# 4   1.442630  -0.024781  -1.363708    2.173076  ...   -1.891802    0.377734
#
#    feature_22  feature_23  feature_24  feature_25  feature_26  feature_27  \
# ...

# %%
print(df['target'].unique())
# Out:
# [0.66559964 0.81359369 1.03523862 ... 0.82866293 0.96541023 0.73097199]

# %%
df['target'] = df['target'].apply(lambda x: 1 if x >= 0.5 else 0)

# %%
print(df['target'].unique())  # Should output [0, 1]
# Out:
# [1 0]

# %%
df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0        0.0   0.917608  -1.183426   1.706060   0.656796  -0.907555
# 1        0.0   1.055596   0.704125   1.188375   1.549320  -1.728858
# 2        0.0   0.642728  -1.665541  -0.531798   1.339529   1.096409
# 3        0.0   0.371874   0.716787   0.157442   0.534731  -1.075644
# 4        1.0   1.834300   0.114874   0.305590   0.416167  -0.468590
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_20  feature_21  \
# 0   0.633189  -1.169487  -0.808778    0.000000  ...   -1.330480    1.559696
# 1   1.054307  -2.541946  -0.295424    0.000000  ...    0.360152   -0.620104
# 2   1.029848   1.135768  -0.410179    0.000000  ...   -0.914068    1.361593
# 3   0.701345   0.089095   1.661624    0.000000  ...   -0.948214    1.549708
# 4   1.442630  -0.024781  -1.363708    2.173076  ...   -1.891802    0.377734
#
#    feature_22  feature_23  feature_24  feature_25  feature_26  feature_27  \
# ...

# %%
import matplotlib.pyplot as plt

df.iloc[:, :-1].hist(bins=20, figsize=(20, 15))
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(15, 10))
sns.boxplot(data=df.iloc[:, :-1])
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = df.iloc[:, :-1]
y = df['target']

X_scaled = scaler.fit_transform(X)

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X_scaled)

# %%
from sklearn.feature_selection import RFE
from sklearn.svm import SVC
svc = SVC(kernel='linear')
rfe = RFE(estimator=svc, n_features_to_select=10)
X_selected = rfe.fit_transform(X_scaled, y)
print(rfe.support_)  # Selected features
# Out:
# [False False False False  True False False False False False False  True
#   True False False False False False  True False  True False False  True
#   True  True  True  True]

# %%
from sklearn.feature_selection import SelectKBest, f_classif

select_k_best = SelectKBest(score_func=f_classif, k=10)
X_selected = select_k_best.fit_transform(X_scaled, y)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

svc = SVC(kernel='linear')
scores = cross_val_score(svc, X_selected, y, cv=5, scoring='accuracy')
print("Accuracy:", scores.mean())
# Out:
# Accuracy: 0.9987271900450618

# %%
from sklearn.metrics import classification_report, roc_auc_score

svc.fit(X_selected, y)
y_pred = svc.predict(X_selected)

print(classification_report(y, y_pred))
auc = roc_auc_score(y, y_pred)
print(f'AUC: {auc}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       1.00      1.00      1.00     10985
#
#     accuracy                           1.00     10999
#    macro avg       0.50      0.50      0.50     10999
# weighted avg       1.00      1.00      1.00     10999
#
# AUC: 0.5
# /home/jatin/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jatin/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.linear_model import SGDClassifier

sgd_svm = SGDClassifier(loss='hinge', max_iter=1000)
sgd_svm.fit(X_selected, y)
# Out:
# SGDClassifier()

# %%
svc_poly = SVC(kernel='poly', degree=3)
scores_poly = cross_val_score(svc_poly, X_selected, y, cv=5)
print("Polynomial Kernel Accuracy:", scores_poly.mean())
# Out:
# Polynomial Kernel Accuracy: 0.9987271900450618

# %%
svc_rbf = SVC(kernel='rbf', gamma=0.1)
scores_rbf = cross_val_score(svc_rbf, X_selected, y, cv=5)
print("RBF Kernel Accuracy:", scores_rbf.mean())
# Out:
# RBF Kernel Accuracy: 0.9987271900450618

# %%
import numpy as np

def custom_kernel(X, Y):
    return np.dot(X, Y.T) + np.exp(-0.1 * np.linalg.norm(X - Y, axis=1))

svc_custom = SVC(kernel=custom_kernel)
svc_custom.fit(X_selected, y)
# Out:
# SVC(kernel=<function custom_kernel at 0x76d1775780e0>)

# %%
import numpy as np

def custom_kernel(X, Y):
    return np.dot(X, Y.T) + np.exp(-0.1 * np.linalg.norm(X - Y, axis=1))

svc_custom = SVC(kernel=custom_kernel)
svc_custom.fit(X_selected, y)
# Out:
# SVC(kernel=<function custom_kernel at 0x76d19eadec00>)

# %%
# Fit the SVM model with RBF kernel
svc_rbf = SVC(kernel='rbf', gamma=0.1)
svc_rbf.fit(X_selected, y)  # Make sure to fit the model first
# Out:
# SVC(gamma=0.1)

# %%
import shap

# Use k-means clustering to summarize the background data into 10 clusters
X_background_kmeans = shap.kmeans(X_selected, 10)

# Initialize the SHAP explainer with the summarized background data
explainer = shap.KernelExplainer(svc_rbf.predict, X_background_kmeans)

# Get SHAP values for a subset of 100 data points
shap_values = explainer.shap_values(X_selected[:100])

# Plot the SHAP summary plot
shap.summary_plot(shap_values, X_selected[:100])
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 21.21it/s]
